# %%
import numpy as np
import pandas as pd
import keras
import os

from PIL import Image

# %%
def get_count(dir_path):
    count = 0
    for path in os.listdir(dir_path):
        count += 1
    
    print('Original Images count:', count)
    print('Tampered Images count:', count)


print('Training data:')
get_count('../input/cg1050/TRAINING_CG-1050/TRAINING/ORIGINAL')

print('\nValidation data:')
get_count('../input/cg1050/VALIDATION_CG-1050/VALIDATION/ORIGINAL')
# Out:
# Training data:
# Original Images count: 730
# Tampered Images count: 730
#
# Validation data:
# Original Images count: 314
# Tampered Images count: 314

# %%
original = Image.open('../input/cg1050/TRAINING_CG-1050/TRAINING/ORIGINAL/Im100_2_cm.jpg')
original
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=895x331 at 0x7B3F3BB7A650>

# %%
tampered = Image.open('../input/cg1050/TRAINING_CG-1050/TRAINING/TAMPERED/Im100_cm2.jpg')
tampered
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=895x331 at 0x7B3EC9F8F5D0>

# %%
from keras.preprocessing.image import ImageDataGenerator

img_shape = (150,150)

datagen = ImageDataGenerator()

training_data = datagen.flow_from_directory('../input/cg1050/TRAINING_CG-1050/TRAINING/',
                                            target_size=img_shape,
                                            color_mode='rgb',
                                            batch_size=64,
                                            seed=32,
                                            interpolation='bicubic')

validation_data = datagen.flow_from_directory('../input/cg1050/VALIDATION_CG-1050/VALIDATION/',
                                                    target_size=img_shape,
                                                    color_mode='rgb',
                                                    batch_size=64,
                                                    seed=32,
                                                    interpolation='bicubic')
# Out:
# Found 1460 images belonging to 2 classes.
# Found 628 images belonging to 2 classes.

# %%
import keras.models as M
import keras.layers as L
from tensorflow_addons.layers import InstanceNormalization as IN

def make_model():
    model=M.Sequential()
    model.add(L.Conv2D(filters=32,kernel_size=(3,3),padding='same',strides=2,activation="relu",input_shape=(150,150,3)))
    model.add(IN(axis=-1))
    model.add(L.MaxPooling2D(pool_size=(2,2)))
    model.add(L.Conv2D(filters=64,kernel_size=(3,3),padding='same',strides=2))
    model.add(L.MaxPooling2D(pool_size=(2,2)))
    model.add(L.Dropout(0.4))
    model.add(L.Conv2D(filters=128,kernel_size=(3,3),padding='same',strides=2))
    model.add(L.MaxPooling2D(pool_size=(2,2)))
    model.add(L.Flatten())
    model.add(L.Dense(100,'relu'))
    model.add(L.Dropout(0.4))
    model.add(L.Dense(2,'softmax'))
    model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
    return model

model=make_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 75, 75, 32)        896
# _________________________________________________________________
# instance_normalization (Inst (None, 75, 75, 32)        64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 37, 37, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 19, 19, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 9, 64)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 9, 9, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 5, 128)         73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 100)               51300
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 202
# =================================================================
# Total params: 144,814
# Trainable params: 144,814
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stop=keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=4)
reduce_lr=keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy',patience=2)
model.fit(training_data,validation_data=validation_data,epochs=40,callbacks=[reduce_lr])
# Out:
# Epoch 1/40
# 23/23 [==============================] - 42s 1s/step - loss: 0.8344 - accuracy: 0.5315 - val_loss: 0.6687 - val_accuracy: 0.5924
# Epoch 2/40
# 23/23 [==============================] - 22s 968ms/step - loss: 0.6748 - accuracy: 0.5829 - val_loss: 0.6706 - val_accuracy: 0.5971
# Epoch 3/40
# 23/23 [==============================] - 21s 942ms/step - loss: 0.6685 - accuracy: 0.5993 - val_loss: 0.6492 - val_accuracy: 0.6099
# Epoch 4/40
# Epoch 26/40
# 23/23 [==============================] - 21s 945ms/step - loss: 0.6078 - accuracy: 0.6589 - val_loss: 0.6280 - val_accuracy: 0.6481
# Epoch 27/40
# 23/23 [==============================] - 21s 947ms/step - loss: 0.6090 - accuracy: 0.6582 - val_loss: 0.6280 - val_accuracy: 0.6481
# Epoch 28/40
# 23/23 [==============================] - 21s 941ms/step - loss: 0.5968 - accuracy: 0.6719 - val_loss: 0.6280 - val_accuracy: 0.6481
# Epoch 29/40
# 23/23 [==============================] - 22s 961ms/step - loss: 0.6035 - accuracy: 0.6603 - val_loss: 0.6280 - val_accuracy: 0.6481
# Epoch 30/40
# 23/23 [==============================] - 22s 958ms/step - loss: 0.6024 - accuracy: 0.6610 - val_loss: 0.6280 - val_accuracy: 0.6481
# Epoch 31/40
# 23/23 [==============================] - 21s 942ms/step - loss: 0.6076 - accuracy: 0.6623 - val_loss: 0.6280 - val_accuracy: 0.6481
# Epoch 32/40
# 23/23 [==============================] - 22s 952ms/step - loss: 0.6034 - accuracy: 0.6658 - val_loss: 0.6280 - val_accuracy: 0.6481
# Epoch 33/40
# 23/23 [==============================] - 21s 936ms/step - loss: 0.6052 - accuracy: 0.6760 - val_loss: 0.6280 - val_accuracy: 0.6481
# Epoch 34/40
# 23/23 [==============================] - 22s 954ms/step - loss: 0.5981 - accuracy: 0.6719 - val_loss: 0.6280 - val_accuracy: 0.6481
# Epoch 35/40
# 23/23 [==============================] - 22s 958ms/step - loss: 0.5998 - accuracy: 0.6699 - val_loss: 0.6280 - val_accuracy: 0.6481
# Epoch 36/40
# 23/23 [==============================] - 21s 944ms/step - loss: 0.6009 - accuracy: 0.6575 - val_loss: 0.6280 - val_accuracy: 0.6481
# Epoch 37/40
# 23/23 [==============================] - 21s 937ms/step - loss: 0.5975 - accuracy: 0.6623 - val_loss: 0.6280 - val_accuracy: 0.6481
# Epoch 38/40
# 23/23 [==============================] - 22s 940ms/step - loss: 0.5974 - accuracy: 0.6664 - val_loss: 0.6280 - val_accuracy: 0.6481
# Epoch 39/40
# 23/23 [==============================] - 21s 929ms/step - loss: 0.6061 - accuracy: 0.6678 - val_loss: 0.6280 - val_accuracy: 0.6481
# Epoch 40/40
# 23/23 [==============================] - 22s 944ms/step - loss: 0.6065 - accuracy: 0.6664 - val_loss: 0.6280 - val_accuracy: 0.6481

# %%
import matplotlib.pyplot as plt

loss=model.history.history['loss']
val_loss=model.history.history['val_loss']
acc=model.history.history['accuracy']
val_acc=model.history.history['val_accuracy']
epochs=[i for i in range(len(loss))]
plt.plot(epochs,loss)
plt.plot(epochs,val_loss)
plt.show();

# %%
plt.plot(epochs,acc)
plt.plot(epochs,val_acc)
plt.show();

# %%
import cv2

def predict_image(path):
    image=cv2.imread(path)
    image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
    plt.imshow(image)
    image=cv2.resize(image,(150,150))
    image=image.reshape(1,150,150,3)
    prediction=np.argmax(model.predict(image))
    labels=['Tampered','Original']
    return labels[prediction]

# %%
predict_image('../input/cg1050/VALIDATION_CG-1050/VALIDATION/ORIGINAL/Im100_1_cm.jpg')
# Out:
# 'Original'

# %%
predict_image('../input/cg1050/VALIDATION_CG-1050/VALIDATION/TAMPERED/Im100_cm1.jpg')
# Out:
# 'Original'
