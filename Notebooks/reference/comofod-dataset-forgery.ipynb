# %%
import os
import cv2
import numpy as np 
from tqdm import tqdm
import matplotlib.pyplot as plt
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.utils import *
os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"
import tensorflow as tf

# %%
stretegy = tf.distribute.MirroredStrategy(["GPU:0", "GPU:1"])
print(stretegy.num_replicas_in_sync)
# Out:
# 2

# %%
os.makedirs("dataset/labels")
os.makedirs("dataset/images")
os.makedirs("dataset/masks")

# %%
images = os.listdir("../input/comofod/CoMoFoD_small_v2/")
print("Total image found: {}".format(len(images)))
# Out:
# Total image found: 10402

# %%
for image in tqdm(images):
    if len(image.split("_")) == 2:
        if "B" in image:
            os.system("cp ../input/comofod/CoMoFoD_small_v2/{} ./dataset/labels/".format(image))
    if len(image.split("_")) == 2:
        if "M" in image:
            os.system("cp ../input/comofod/CoMoFoD_small_v2/{} ./dataset/masks/".format(image))
    if len(image.split("_")) > 2:
        if "F" in image:
            os.system("cp ../input/comofod/CoMoFoD_small_v2/{} ./dataset/images/".format(image))
    if len(image.split("_")) > 2:
        if "O" in image:
            os.system("cp ../input/comofod/CoMoFoD_small_v2/{} ./dataset/images/".format(image))
# Out:
# 100%|██████████| 10402/10402 [02:39<00:00, 65.39it/s]

# %%
print("Total Labels: ", len(os.listdir("dataset/labels/")))
print("Total Masks: ", len(os.listdir("dataset/masks/")))
print("Total Forged Images: ", len(os.listdir("dataset/images/")))
# Out:
# Total Labels:  200
# Total Masks:  200
# Total Forged Images:  9600

# %%
def unet(input_size=(256, 256, 1)):
    inputs = Input(input_size)
    conv1 = Conv2D(16, 3, activation='relu', padding='same', kernel_initializer='he_normal')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(16, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    
    conv2 = Conv2D(32, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(32, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    
    conv3 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    
    conv4 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv4)
    conv4 = BatchNormalization()(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool4)
    conv5 = BatchNormalization()(conv5)

    conv5 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv5)
    conv5 = BatchNormalization()(conv5)

    up6 = Conv2D(128, 2, activation='relu', padding='same', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(conv5))
    up6 = BatchNormalization()(up6)
    merge6 = concatenate([conv4, up6], axis=3)
    conv6 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge6)
    conv6 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv6)

    up7 = Conv2D(64, 2, activation='relu', padding='same', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(conv6))
    up7 = BatchNormalization()(up7)
    merge7 = concatenate([conv3, up7], axis=3)
    conv7 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge7)
    conv7 = BatchNormalization()(conv7)
    conv7 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv7)
    conv7 = BatchNormalization()(conv7)
    
    up8 = Conv2D(32, 2, activation='relu', padding='same', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(conv7))
    up8 = BatchNormalization()(up8)
    merge8 = concatenate([conv2, up8], axis=3)
    conv8 = Conv2D(32, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Conv2D(32, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv8)
    conv8 = BatchNormalization()(conv8)
    
    up9 = Conv2D(16, 2, activation='relu', padding='same', kernel_initializer='he_normal')(
        UpSampling2D(size=(2, 2))(conv8))
    up9 = BatchNormalization()(up9)
    merge9 = concatenate([conv1, up9], axis=3)
    conv9 = Conv2D(16, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge9)
    conv9 = BatchNormalization()(conv9)
    conv9 = Conv2D(16, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv9)
    conv9 = BatchNormalization()(conv9)
    conv9 = Conv2D(2, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv9)
    conv9 = BatchNormalization()(conv9)
    conv10 = Conv2D(1, 1, activation='sigmoid')(conv9)

    model = Model(inputs=inputs, outputs=conv10)

    return model

# %%
image = cv2.imread("dataset/images/001_F_BC1.png", cv2.IMREAD_COLOR)
mask = cv2.imread("dataset/labels/001_B.png")
cropped_image = cv2.imread("dataset/masks/001_M.png")
auth_image = cv2.imread("dataset/images/001_O_BC1.png")
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 20))
ax1.imshow(image)
ax2.imshow(mask)
ax3.imshow(cropped_image)
ax4.imshow(auth_image)

# %%
train_test_images = os.listdir("dataset/images")
train_images = train_test_images[:int(0.9 * len(train_test_images))]
test_images = train_test_images[int(0.9 * len(train_test_images)):]

print("Training Images: {}".format(len(train_images)))
print("Testing Images: {}".format(len(test_images)))
# Out:
# Training Images: 8640
# Testing Images: 960

# %%
def adjust_data(image, mask):
    image = image / 255
    mask = mask / 255
    
    return image, mask

def get_dct(image, block_size):
    height, width = image.shape[:2]
    w_block = int(height/block_size)
    h_block = int(width/block_size)

    gray_image = np.zeros((height, width), np.float32)
    dct_block_image = np.zeros((height, width), np.float32)

    gray_image[:height, :width] = image
    for row in range(w_block):
        for col in range(h_block):
            currunt_block = cv2.dct(gray_image[row*block_size:(row + 1)*block_size, col*block_size: (col + 1)*block_size])
            dct_block_image[row*block_size: (row + 1)*block_size, col*block_size:(col + 1)*block_size] = currunt_block

    return dct_block_image

class DataLoader(Sequence):
    
    def __init__(self, dataset_list,
                batch_size):
        self.dataset_list = dataset_list
        self.batch_size = batch_size
        np.random.shuffle(self.dataset_list)
        
    def on_epoch_end(self):
        pass
        
    def __len__(self):
        return len(self.dataset_list) // self.batch_size
        
    def __getitem__(self, index):
        i = index * self.batch_size
        batch_input_data = self.dataset_list[i : i + self.batch_size]
        x = np.zeros((self.batch_size, 256, 256, 1), dtype=np.float32)
        y = np.zeros((self.batch_size, 256, 256, 1), dtype=np.float32)
        for j, image_name in enumerate(batch_input_data):
            image = cv2.imread("dataset/images/{}".format(image_name), cv2.IMREAD_GRAYSCALE)
            image = cv2.resize(image, (256, 256))
            image = get_dct(image, 8)
            image = np.expand_dims(image, -1)
            if "O" not in image_name:
                mask = cv2.imread("dataset/labels/{}_B.png".format(image_name.split("_")[0]), cv2.IMREAD_GRAYSCALE)
                mask = cv2.resize(mask, (256, 256))
                mask = np.reshape(mask, (256, 256, 1))
            else:
                mask = np.zeros((256, 256, 1), dtype=np.float32)
            x[j] = image
            y[j] = mask       
            
        return adjust_data(x,y)

# %%
train_datagen = DataLoader(train_images, 128)

# %%
with stretegy.scope():
    model = unet()
    model.compile(optimizer=Adam(lr=1e-4), loss='binary_crossentropy', metrics=['accuracy'])
    model_checkpoint = ModelCheckpoint('unet.hdf5', monitor="loss", verbose=1, save_best_only=True)
history = model.fit_generator(train_datagen, epochs=40, callbacks=[model_checkpoint], verbose=1)
# Out:
# 2022-11-09 02:22:05.583926: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 33554432 exceeds 10% of free system memory.
# 2022-11-09 02:22:05.621569: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 33554432 exceeds 10% of free system memory.
# 2022-11-09 02:22:05.687189: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:695] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_2"
# op: "FlatMapDataset"
# input: "TensorDataset/_1"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_flat_map_fn_37610"
#     }
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#         dim {
#           size: -1
#         }
#         dim {
#           size: -1
#         }
#         dim {
#           size: -1
#         }
#       }
#       shape {
#         dim {
#           size: -1
#         }
#         dim {
#           size: -1
#         }
#         dim {
#           size: -1
#         }
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_FLOAT
#       type: DT_FLOAT
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# Epoch 1/40
# 2022-11-09 02:22:41.672998: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 33554432 exceeds 10% of free system memory.
# 2022-11-09 02:22:41.720858: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 33554432 exceeds 10% of free system memory.
# 2022-11-09 02:22:43.846511: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 33554432 exceeds 10% of free system memory.
# 67/67 [==============================] - 162s 2s/step - loss: 0.7160 - accuracy: 0.3870
#
# Epoch 00001: loss improved from inf to 0.71599, saving model to unet.hdf5
# Epoch 2/40
# 67/67 [==============================] - 122s 2s/step - loss: 0.6682 - accuracy: 0.8374
#
# Epoch 00002: loss improved from 0.71599 to 0.66817, saving model to unet.hdf5
# Epoch 3/40
# 67/67 [==============================] - 124s 2s/step - loss: 0.6518 - accuracy: 0.8974
#
# Epoch 00003: loss improved from 0.66817 to 0.65177, saving model to unet.hdf5
# Epoch 4/40
# 67/67 [==============================] - 125s 2s/step - loss: 0.6390 - accuracy: 0.9273
#
# Epoch 00004: loss improved from 0.65177 to 0.63898, saving model to unet.hdf5
# Epoch 5/40
# 67/67 [==============================] - 125s 2s/step - loss: 0.6281 - accuracy: 0.9438
#
# Epoch 00005: loss improved from 0.63898 to 0.62809, saving model to unet.hdf5
# Epoch 6/40
# 67/67 [==============================] - 123s 2s/step - loss: 0.6168 - accuracy: 0.9581
#
# Epoch 00006: loss improved from 0.62809 to 0.61685, saving model to unet.hdf5
# Epoch 7/40
# 67/67 [==============================] - 124s 2s/step - loss: 0.6067 - accuracy: 0.9648
#
# Epoch 00007: loss improved from 0.61685 to 0.60666, saving model to unet.hdf5
# Epoch 8/40
# 67/67 [==============================] - 124s 2s/step - loss: 0.5964 - accuracy: 0.9677
#
# Epoch 00008: loss improved from 0.60666 to 0.59639, saving model to unet.hdf5
# Epoch 9/40
# 67/67 [==============================] - 124s 2s/step - loss: 0.5855 - accuracy: 0.9685
#
# Epoch 00009: loss improved from 0.59639 to 0.58547, saving model to unet.hdf5
# Epoch 10/40
# 67/67 [==============================] - 123s 2s/step - loss: 0.5745 - accuracy: 0.9725
#
# Epoch 00010: loss improved from 0.58547 to 0.57450, saving model to unet.hdf5
# Epoch 11/40
# 67/67 [==============================] - 123s 2s/step - loss: 0.5648 - accuracy: 0.9766
#
# Epoch 00011: loss improved from 0.57450 to 0.56483, saving model to unet.hdf5
# Epoch 12/40
# 67/67 [==============================] - 123s 2s/step - loss: 0.5553 - accuracy: 0.9799
#
# Epoch 00012: loss improved from 0.56483 to 0.55529, saving model to unet.hdf5
# Epoch 13/40
# 67/67 [==============================] - 122s 2s/step - loss: 0.5490 - accuracy: 0.9800
#
# Epoch 00013: loss improved from 0.55529 to 0.54905, saving model to unet.hdf5
# Epoch 14/40
# 67/67 [==============================] - 121s 2s/step - loss: 0.5396 - accuracy: 0.9820
#
# Epoch 00014: loss improved from 0.54905 to 0.53961, saving model to unet.hdf5
# Epoch 15/40
# 67/67 [==============================] - 121s 2s/step - loss: 0.5307 - accuracy: 0.9841
#
# Epoch 00015: loss improved from 0.53961 to 0.53072, saving model to unet.hdf5
# Epoch 16/40
# 67/67 [==============================] - 122s 2s/step - loss: 0.5218 - accuracy: 0.9849
#
# Epoch 00016: loss improved from 0.53072 to 0.52183, saving model to unet.hdf5
# Epoch 17/40
# 67/67 [==============================] - 121s 2s/step - loss: 0.5131 - accuracy: 0.9860
#
# Epoch 00017: loss improved from 0.52183 to 0.51306, saving model to unet.hdf5
# Epoch 18/40
# 67/67 [==============================] - 121s 2s/step - loss: 0.5115 - accuracy: 0.9823
#
# Epoch 00018: loss improved from 0.51306 to 0.51151, saving model to unet.hdf5
# Epoch 19/40
# 67/67 [==============================] - 122s 2s/step - loss: 0.4982 - accuracy: 0.9861
#
# Epoch 00019: loss improved from 0.51151 to 0.49815, saving model to unet.hdf5
# Epoch 20/40
# 67/67 [==============================] - 122s 2s/step - loss: 0.4894 - accuracy: 0.9871
#
# Epoch 00020: loss improved from 0.49815 to 0.48942, saving model to unet.hdf5
# Epoch 21/40
# 67/67 [==============================] - 122s 2s/step - loss: 0.4810 - accuracy: 0.9879
#
# Epoch 00021: loss improved from 0.48942 to 0.48104, saving model to unet.hdf5
# Epoch 22/40
# 67/67 [==============================] - 119s 2s/step - loss: 0.4741 - accuracy: 0.9877
#
# Epoch 00022: loss improved from 0.48104 to 0.47414, saving model to unet.hdf5
# Epoch 23/40
# 67/67 [==============================] - 121s 2s/step - loss: 0.4741 - accuracy: 0.9837
#
# Epoch 00023: loss improved from 0.47414 to 0.47412, saving model to unet.hdf5
# Epoch 24/40
# 67/67 [==============================] - 121s 2s/step - loss: 0.4605 - accuracy: 0.9870
#
# Epoch 00024: loss improved from 0.47412 to 0.46053, saving model to unet.hdf5
# Epoch 25/40
# 67/67 [==============================] - 121s 2s/step - loss: 0.4513 - accuracy: 0.9880
#
# Epoch 00025: loss improved from 0.46053 to 0.45135, saving model to unet.hdf5
# Epoch 26/40
# 67/67 [==============================] - 120s 2s/step - loss: 0.4428 - accuracy: 0.9890
#
# Epoch 00026: loss improved from 0.45135 to 0.44282, saving model to unet.hdf5
# Epoch 27/40
# 67/67 [==============================] - 123s 2s/step - loss: 0.4348 - accuracy: 0.9894
#
# Epoch 00027: loss improved from 0.44282 to 0.43485, saving model to unet.hdf5
# Epoch 28/40
# 67/67 [==============================] - 121s 2s/step - loss: 0.4270 - accuracy: 0.9897
#
# Epoch 00028: loss improved from 0.43485 to 0.42698, saving model to unet.hdf5
# Epoch 29/40
# 67/67 [==============================] - 120s 2s/step - loss: 0.4193 - accuracy: 0.9900
#
# Epoch 00029: loss improved from 0.42698 to 0.41929, saving model to unet.hdf5
# Epoch 30/40
# 67/67 [==============================] - 119s 2s/step - loss: 0.4120 - accuracy: 0.9903
#
# Epoch 00030: loss improved from 0.41929 to 0.41200, saving model to unet.hdf5
# Epoch 31/40
# 67/67 [==============================] - 121s 2s/step - loss: 0.4042 - accuracy: 0.9905
#
# Epoch 00031: loss improved from 0.41200 to 0.40418, saving model to unet.hdf5
# Epoch 32/40
# 67/67 [==============================] - 121s 2s/step - loss: 0.3965 - accuracy: 0.9908
#
# Epoch 00032: loss improved from 0.40418 to 0.39652, saving model to unet.hdf5
# Epoch 33/40
# 67/67 [==============================] - 120s 2s/step - loss: 0.3890 - accuracy: 0.9910
#
# Epoch 00033: loss improved from 0.39652 to 0.38904, saving model to unet.hdf5
# Epoch 34/40
# 67/67 [==============================] - 120s 2s/step - loss: 0.3820 - accuracy: 0.9909
#
# Epoch 00034: loss improved from 0.38904 to 0.38202, saving model to unet.hdf5
# Epoch 35/40
# 67/67 [==============================] - 121s 2s/step - loss: 0.3741 - accuracy: 0.9909
#
# Epoch 00035: loss improved from 0.38202 to 0.37409, saving model to unet.hdf5
# Epoch 36/40
# 67/67 [==============================] - 121s 2s/step - loss: 0.3648 - accuracy: 0.9901
#
# Epoch 00036: loss improved from 0.37409 to 0.36484, saving model to unet.hdf5
# Epoch 37/40
# 67/67 [==============================] - 120s 2s/step - loss: 0.3492 - accuracy: 0.9850
#
# Epoch 00037: loss improved from 0.36484 to 0.34925, saving model to unet.hdf5
# Epoch 38/40
# 67/67 [==============================] - 120s 2s/step - loss: 0.3377 - accuracy: 0.9874
#
# Epoch 00038: loss improved from 0.34925 to 0.33769, saving model to unet.hdf5
# Epoch 39/40
# 67/67 [==============================] - 121s 2s/step - loss: 0.3260 - accuracy: 0.9886
#
# Epoch 00039: loss improved from 0.33769 to 0.32604, saving model to unet.hdf5
# Epoch 40/40
# 67/67 [==============================] - 121s 2s/step - loss: 0.3155 - accuracy: 0.9900
#
# Epoch 00040: loss improved from 0.32604 to 0.31555, saving model to unet.hdf5

# %%
test_datagen = DataLoader(test_images, 8)
result = model.predict(test_datagen, verbose=0)
# Out:
# 2022-11-09 03:44:14.346611: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:695] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_2"
# op: "FlatMapDataset"
# input: "TensorDataset/_1"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_flat_map_fn_110360"
#     }
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#         dim {
#           size: -1
#         }
#         dim {
#           size: -1
#         }
#         dim {
#           size: -1
#         }
#       }
#       shape {
#         dim {
#           size: -1
#         }
#         dim {
#           size: -1
#         }
#         dim {
#           size: -1
#         }
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_FLOAT
#       type: DT_FLOAT
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.

# %%
for i, res in enumerate(result[50:60]):
    image_name = test_images[i + 50]
    image = cv2.imread("dataset/images/{}".format(image_name), cv2.IMREAD_COLOR)
    image = cv2.resize(image, (256, 256))
    if "O" not in image_name:
        mask = cv2.imread("dataset/labels/{}_B.png".format(image_name.split("_")[0]), cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, (256, 256))
    else:
        mask = np.zeros((256, 256, 1), dtype=np.float32)
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 20))
    ax1.imshow(image)
    ax2.imshow(mask)
    ax3.imshow(res)

# %%
iou = []
mean_iou = 0
for i, res in enumerate(result):
    image_name = test_images[i]
    if "O" not in image_name:
        mask = cv2.imread("dataset/labels/{}_B.png".format(image_name.split("_")[0]), cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, (256, 256))
    else:
        mask = np.zeros((256, 256, 1), dtype=np.float32)
    res[res>0.5] = 1
    res[res<0.5] = 0
    m = tf.keras.metrics.MeanIoU(num_classes=2)
    m.update_state(res, mask/255)
    mean_iou = mean_iou + m.result().numpy()
    iou.append(m.result().numpy())

# %%
print("Accuracy of model:", mean_iou/len(result)*100)
# Out:
# Accuracy of model: 79.28151290863752
